# %%
import pandas as pd
import numpy as np
import os
import re
from sentence_transformers import SentenceTransformer, util
import torch
from collections import defaultdict
from transformers import pipeline

# %% [markdown]
# ## Phase 1: Load Dataset & Generate Embedding

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

folder_path = '/content/drive/My Drive/IC/'

file_names = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

frames = []
for name in file_names:

    year_match = re.search(r'(\d{4})', name)

    year = int(year_match.group(1))
    temp_df = pd.read_csv(os.path.join(folder_path, name))
    temp_df['Year'] = year
    frames.append(temp_df)


df = pd.concat(frames, ignore_index=True)
print(f"Successfully loaded {len(frames)} CSV files. Total comments: {len(df)}")
print(f"Years found: {sorted(df['Year'].unique())}")
# Out:
# Mounted at /content/drive
# /tmp/ipython-input-355167205.py:14: DtypeWarning: Columns (3,5,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(os.path.join(folder_path, name))
# /tmp/ipython-input-355167205.py:14: DtypeWarning: Columns (3,5,42,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(os.path.join(folder_path, name))
# /tmp/ipython-input-355167205.py:14: DtypeWarning: Columns (3,5,42,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(os.path.join(folder_path, name))
# /tmp/ipython-input-355167205.py:14: DtypeWarning: Columns (3,5,42,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(os.path.join(folder_path, name))
# /tmp/ipython-input-355167205.py:14: DtypeWarning: Columns (3,5,13,42,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(os.path.join(folder_path, name))
# /tmp/ipython-input-355167205.py:14: DtypeWarning: Columns (3,5,42,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(os.path.join(folder_path, name))
# Successfully loaded 6 CSV files. Total comments: 375038
# Years found: [np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022)]

# %%
hcf_dimensions = {
    "Direct Management": """A supervisor-subordinate relationship is inherently hierarchal, which also
    means that it is inherently complex with multiple potential points of failure. Getting instructions
    about what to do and how to do it are never easy as it decreases the sense of autonomy in
    multiple ways. In this dimension we assess the positive qualities of these relationships with an
    emphasis on the working relationship, the support of employee development and on general
    caring for the employee. In general, positive manager-employee relationships encourages
    productivity and collaboration among teams. When there’s mutual respect, care, and
    communications between a manager and an employee, there’s more willingness on both ends to
    offer support and perform well.""",

    "Organizational Alignment": """Organizational alignment is a shared understanding of the positive
    mission, philosophy and approaches that underlie the path and methods of any company. It
    allows all members of an organization, from entry-level positions to executive managers, to
    share common goals and vision for the organization and to be proud of their joint mission. In
    this dimension we assess the connection employees have with the values of the company, the
    sense of mission, and the meaning that they get from their workplace. In general, good
    organizational alignment helps with both motivation toward common organizational goals, a
    shared understanding of how to treat each other to accomplish goals, and the coordination of all
    actions and actors toward that goal.""",

    "Engagement": """Engagement is the level of commitment and emotional investment that employees
    have toward their job and their organization. Engagement is not just about job satisfaction or
    happiness, it is also about the level of involvement with their job, colleagues, and organization.
    Engaged employees are enthusiastic about their work, are willing to go above and beyond what
    is expected of them and are more likely to be loyal to their employer. In this dimension we
    assess motivation, connection with the company, and the ability of the employee to reach their
    potential to address the difficulties present in any job. In general, high employee engagement is
    crucial for creating a positive and productive workplace culture that fosters growth and success
    for both employees and the company.""",

    "Innovation": """Innovation is the process of creating something new or improved. It involves
    finding, testing, and improving novel and creative solutions to problems or challenges. It also
    involves developing new ideas, products, or services. Innovation is an important driver of
    progress and growth for all companies. In this dimension we assess the company’s approach to
    innovation and the degree to which it implicitly and explicitly encourages or discourages it, from
    a company’s treatment of mistakes to the outright acceptance of new ideas. In general, the more
    innovative a company is, the more likely it is to be successful over time.""",

    "Organizational Effectiveness": """Organizational effectiveness is the ability of a group to achieve
    its goals and objectives efficiently and with little waste (inputs, effort, time, energy, attention).
    Organizational effectiveness is a reflection of how well an organization uses its human and non-human
    resources to achieve its mission and objectives. In this dimension we assess whether
    people are given the tools they need for their jobs, the degree of collaboration, and the level of
    bureaucratic burden. In general, organizations with a high degree of organizational
    effectiveness are like well-oiled machines, providing a high level of output with inputs available.""",

    "Emotional Connection": """Emotional connection is the feeling of being emotionally attached,
    invested, and engaged with the workplace and co-workers. When employees feel emotionally
    connected, they are more likely to invest time, energy, and resources. Emotional connection can
    also foster trust, loyalty, and commitment. In this dimension we assess the desire to stay at the
    workplace, see their futures as intertwined, and the desire to recommend the workplace to others.
    In general, high emotional connection brings a sense of connection, satisfaction, productivity,
    purpose, and fulfillment.""",

    "Extrinsic Rewards": """Extrinsic rewards refer to rewards that are external to an individual such as
    money, prizes, or recognition. These rewards are intended to motivate the individual to perform
    better or continue engaging in a certain behavior, but do they?
    Extrinsic rewards have been shown to be effective in motivating individuals in the short term.
    However, extrinsic rewards have some limitations and are often ineffective in motivating
    individuals in the long term, as they do not address intrinsic motivation or interest in the work
    itself. In some cases, extrinsic rewards can have a negative effect on intrinsic motivation as
    individuals become over-focused on the reward itself. In this dimension we assess
    compensation, opportunities for advancement, and benefits. In general, when we think about
    rewards, we usually think about a set of extrinsic rewards."""
}

# %%
print("\nLoading Sentence-BERT model...")
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded.")

# embeddings for HCF
print("Generating embeddings for HCF dimensions")
dimension_names = list(hcf_dimensions.keys())
dimension_descriptions = list(hcf_dimensions.values())
hcf_embeddings = model.encode(dimension_descriptions, convert_to_tensor=True)
print("HCF embeddings generated.")

df.dropna(subset=['PROs', 'CONs'], how='all', inplace=True)
df['PROs'] = df['PROs'].fillna('')
df['CONs'] = df['CONs'].fillna('')


# embedding for all comments (PROs and CONs)
print("\nGenerating embeddings for all comments.")
# combine all comments into one list
all_pros = df['PROs'][df['PROs'] != ''].tolist()
all_cons = df['CONs'][df['CONs'] != ''].tolist()

# encode PROs and CONs separately to map them back easily
pro_embeddings = model.encode(all_pros, convert_to_tensor=True, show_progress_bar=True)
con_embeddings = model.encode(all_cons, convert_to_tensor=True, show_progress_bar=True)

# create dictionaries to map comments back to their embeddings
pro_embedding_map = {comment: emb for comment, emb in zip(all_pros, pro_embeddings)}
con_embedding_map = {comment: emb for comment, emb in zip(all_cons, con_embeddings)}
print("All comment embeddings generated and mapped.")
# Out:
# Loading Sentence-BERT model...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model loaded.
# Generating embeddings for HCF dimensions...
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# HCF embeddings generated.
#
# Generating embeddings for all comments. This may take some time...
# Batches:   0%|          | 0/11720 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Batches:   0%|          | 0/11720 [00:00<?, ?it/s]
# All comment embeddings generated and mapped.

# %% [markdown]
# ## Phase 2: Analysis Loop & Helper Function

# %%
print("\nLoading abstractive summarization models")
summarizer_t5 = pipeline("summarization", model="t5-small", tokenizer="t5-small")
print("T5 model loaded.")
summarizer_bart = pipeline("summarization", model="facebook/bart-large-cnn")
print("BART model loaded.")
# Out:
# Loading abstractive summarization models
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cuda:0
# T5 model loaded.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# BART model loaded.

# %%
def map_comment_to_dimension(comment_embedding, hcf_embeddings, dimension_names):
    """Maps a single comment embedding to the most similar HCF dimension."""
    cosine_scores = util.cos_sim(comment_embedding, hcf_embeddings)
    best_match_index = torch.argmax(cosine_scores).item()
    return dimension_names[best_match_index]

# %%
def summarize_text_abstractive(text_list, summarizer_pipeline):
    """
    Generates a true abstractive summary for a list of comments.
    """
    # combine all comments
    full_text = ". ".join(text_list)
    if len(full_text) < 100:
      return full_text # return original text if too short

    max_input_length = 1024
    truncated_text = full_text[:max_input_length]

    summary_result = summarizer_pipeline(truncated_text, max_new_tokens=40, min_length=15, do_sample=False)
    return summary_result[0]['summary_text']

# %%
def generate_hcf_informed_paragraph(comment_list, embedding_map, summarizer_pipeline):
    """
    Analyzes a list of comments and generates a single summary paragraph
    structured by HCF themes, using the provided summarizer.
    """
    if not comment_list:
        return "No comments provided."

    # map each comment to an HCF dimension
    hcf_buckets = defaultdict(list)
    for comment in comment_list:
        if comment in embedding_map:
            comment_embedding = embedding_map[comment]
            dimension = map_comment_to_dimension(comment_embedding, hcf_embeddings, dimension_names)
            hcf_buckets[dimension].append(comment)

    if not hcf_buckets:
        return "Could not map any comments to HCF dimensions."

    # generate an abstractive "micro-summary" for each HCF dimension bucket
    micro_summaries = []
    for dimension in dimension_names: # Iterate in a fixed order
        if dimension in hcf_buckets:
            comments_in_bucket = hcf_buckets[dimension]
            # summary for this bucket
            bucket_summary = summarize_text_abstractive(comments_in_bucket, summarizer_pipeline)
            micro_summaries.append(f"{dimension}: {bucket_summary}")

    # assemble the final paragraph
    return " ".join(micro_summaries)

# %%
print("\nStarting T5 and BART summarization...")
analysis_results = []


#group ticker
grouped = df.groupby(['Ticker Symbol', 'Year'])

for (ticker, year), group in grouped:
    print(f"Processing {ticker} for year {year}...")

    # segregate comments for the current group
    pros_list = group['PROs'][group['PROs'] != ''].tolist()
    cons_list = group['CONs'][group['CONs'] != ''].tolist()

    # analyze and summarize each side using BOTH models
    pro_summary_t5 = generate_hcf_informed_paragraph(pros_list, pro_embedding_map, summarizer_t5)
    con_summary_t5 = generate_hcf_informed_paragraph(cons_list, con_embedding_map, summarizer_t5)

    pro_summary_bart = generate_hcf_informed_paragraph(pros_list, pro_embedding_map, summarizer_bart)
    con_summary_bart = generate_hcf_informed_paragraph(cons_list, con_embedding_map, summarizer_bart)

    # store result
    analysis_results.append({
        'Ticker': ticker,
        'Year': year,
        'PROs_Summary_T5': pro_summary_t5,
        'CONs_Summary_T5': con_summary_t5,
        'PROs_Summary_BART': pro_summary_bart,
        'CONs_Summary_BART': con_summary_bart,
    })
print("\nAnalysis complete.")
# Out:
# Starting final analysis loop with T5 and BART summarization...
# Processing nasdaq:aapl for year 2017...
# Processing nasdaq:aapl for year 2018...
# Processing nasdaq:aapl for year 2019...
# Processing nasdaq:aapl for year 2020...
# Processing nasdaq:aapl for year 2021...
# Processing nasdaq:aapl for year 2022...
# Processing nasdaq:adsk for year 2017...
# Your max_length is set to 200, but your input_length is only 196. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=98)
# Your max_length is set to 200, but your input_length is only 193. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# Your max_length is set to 200, but your input_length is only 158. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
# Processing nasdaq:adsk for year 2018...
# Your max_length is set to 200, but your input_length is only 123. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Your max_length is set to 200, but your input_length is only 167. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Your max_length is set to 142, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Processing nasdaq:adsk for year 2019...
# Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Processing nasdaq:adsk for year 2020...
# Your max_length is set to 200, but your input_length is only 131. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 142, but your input_length is only 121. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Processing nasdaq:adsk for year 2021...
# Processing nasdaq:adsk for year 2022...
# Processing nasdaq:amzn for year 2017...
# Processing nasdaq:amzn for year 2018...
# Processing nasdaq:amzn for year 2019...
# Processing nasdaq:amzn for year 2020...
# Processing nasdaq:amzn for year 2021...
# Processing nasdaq:amzn for year 2022...
# Processing nasdaq:cprt for year 2017...
# Your max_length is set to 200, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 200, but your input_length is only 31. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 200, but your input_length is only 158. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
# Your max_length is set to 200, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 200, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 142, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 142, but your input_length is only 26. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 142, but your input_length is only 86. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Processing nasdaq:cprt for year 2018...
# Your max_length is set to 200, but your input_length is only 177. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
# Your max_length is set to 200, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 200, but your input_length is only 34. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Your max_length is set to 200, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 200, but your input_length is only 140. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# Your max_length is set to 142, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 142, but your input_length is only 31. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 142, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 142, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Processing nasdaq:cprt for year 2019...
# Your max_length is set to 200, but your input_length is only 31. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 200, but your input_length is only 144. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=72)
# Your max_length is set to 200, but your input_length is only 191. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Your max_length is set to 200, but your input_length is only 121. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 200, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Your max_length is set to 200, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 142, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 142, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 142, but your input_length is only 123. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Your max_length is set to 142, but your input_length is only 121. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 142, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Processing nasdaq:cprt for year 2020...
# Your max_length is set to 200, but your input_length is only 178. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Your max_length is set to 200, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 200, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 200, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 200, but your input_length is only 94. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 142, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 142, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 142, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 142, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Processing nasdaq:cprt for year 2021...
# Your max_length is set to 200, but your input_length is only 157. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# Processing nasdaq:cprt for year 2022...
# Your max_length is set to 200, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 142, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Processing nasdaq:csgp for year 2017...
# Processing nasdaq:csgp for year 2018...
# Processing nasdaq:csgp for year 2019...
# Your max_length is set to 200, but your input_length is only 183. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Your max_length is set to 200, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 142, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 142, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Processing nasdaq:csgp for year 2020...
# Your max_length is set to 200, but your input_length is only 168. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Your max_length is set to 200, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 142, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Processing nasdaq:csgp for year 2021...
# Processing nasdaq:csgp for year 2022...
# Processing nasdaq:fox for year 2018...
# Your max_length is set to 200, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 200, but your input_length is only 183. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Your max_length is set to 142, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Processing nasdaq:fox for year 2019...
# Your max_length is set to 200, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 200, but your input_length is only 129. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 200, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 142, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 142, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 142, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 142, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Processing nasdaq:fox for year 2020...
# Your max_length is set to 200, but your input_length is only 152. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=76)
# Your max_length is set to 200, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 200, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 200, but your input_length is only 177. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
# Your max_length is set to 142, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 142, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Processing nasdaq:fox for year 2021...
# Your max_length is set to 200, but your input_length is only 182. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Processing nasdaq:fox for year 2022...
# Your max_length is set to 200, but your input_length is only 165. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=82)
# Processing nasdaq:goog for year 2017...
# Processing nasdaq:goog for year 2018...
# Processing nasdaq:goog for year 2019...
# Processing nasdaq:goog for year 2020...
# Processing nasdaq:goog for year 2021...
# Processing nasdaq:goog for year 2022...
# Processing nasdaq:msft for year 2017...
# Processing nasdaq:msft for year 2018...
# Processing nasdaq:msft for year 2019...
# Processing nasdaq:msft for year 2020...
# Processing nasdaq:msft for year 2021...
# Processing nasdaq:msft for year 2022...
# Processing nasdaq:nws for year 2017...
# Processing nasdaq:nws for year 2018...
# Your max_length is set to 200, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 200, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 142, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 142, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Processing nasdaq:nws for year 2019...
# Your max_length is set to 200, but your input_length is only 151. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# Your max_length is set to 142, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Processing nasdaq:nws for year 2020...
# Your max_length is set to 200, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Your max_length is set to 142, but your input_length is only 127. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Processing nasdaq:nws for year 2021...
# Your max_length is set to 200, but your input_length is only 192. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 142, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Processing nasdaq:nws for year 2022...
# Your max_length is set to 200, but your input_length is only 193. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# Your max_length is set to 200, but your input_length is only 166. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Your max_length is set to 200, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Your max_length is set to 142, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Processing nasdaq:sbux for year 2017...
# Processing nasdaq:sbux for year 2018...
# Processing nasdaq:sbux for year 2019...
# Token indices sequence length is longer than the specified maximum sequence length for this model (518 > 512). Running this sequence through the model will result in indexing errors
# Processing nasdaq:sbux for year 2020...
# Processing nasdaq:sbux for year 2021...
# Processing nasdaq:sbux for year 2022...
# Processing nasdaq:wtw for year 2017...
# Processing nasdaq:wtw for year 2018...
# Processing nasdaq:wtw for year 2019...
# Processing nasdaq:wtw for year 2020...
# Processing nasdaq:wtw for year 2021...
# Processing nasdaq:wtw for year 2022...
# Processing nasdaq:z for year 2017...
# Your max_length is set to 200, but your input_length is only 135. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 142, but your input_length is only 131. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Processing nasdaq:z for year 2018...
# Your max_length is set to 200, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 200, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Your max_length is set to 142, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 142, but your input_length is only 114. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Processing nasdaq:z for year 2019...
# Your max_length is set to 200, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 142, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Processing nasdaq:z for year 2020...
# Your max_length is set to 200, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Your max_length is set to 200, but your input_length is only 179. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Your max_length is set to 142, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Processing nasdaq:z for year 2021...
# Processing nasdaq:z for year 2022...
# Processing nyse:acn for year 2017...
# Processing nyse:acn for year 2018...
# Processing nyse:acn for year 2019...
# Processing nyse:acn for year 2020...
# Processing nyse:acn for year 2021...
# Processing nyse:acn for year 2022...
# Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Processing nyse:bki for year 2017...
# Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 142, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Processing nyse:bki for year 2018...
# Your max_length is set to 200, but your input_length is only 186. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 142, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Processing nyse:bki for year 2019...
# Your max_length is set to 200, but your input_length is only 189. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# Your max_length is set to 200, but your input_length is only 184. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Processing nyse:bki for year 2020...
# Your max_length is set to 200, but your input_length is only 135. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 200, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 200, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 200, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 200, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 142, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Your max_length is set to 142, but your input_length is only 132. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Your max_length is set to 142, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 142, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 142, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Processing nyse:bki for year 2021...
# Your max_length is set to 200, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 200, but your input_length is only 169. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Your max_length is set to 142, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Processing nyse:bki for year 2022...
# Your max_length is set to 200, but your input_length is only 174. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# Processing nyse:dis for year 2017...
# Processing nyse:dis for year 2018...
# Processing nyse:dis for year 2019...
# Processing nyse:dis for year 2020...
# Processing nyse:dis for year 2021...
# Processing nyse:dis for year 2022...
# Processing nyse:nke for year 2017...
# Processing nyse:nke for year 2018...
# Processing nyse:nke for year 2019...
# Processing nyse:nke for year 2020...
# Processing nyse:nke for year 2021...
# Processing nyse:nke for year 2022...
# Processing nyse:pfe for year 2017...
# Processing nyse:pfe for year 2018...
# Processing nyse:pfe for year 2019...
# Processing nyse:pfe for year 2020...
# Processing nyse:pfe for year 2021...
# Processing nyse:pfe for year 2022...
# Processing nyse:qsr for year 2017...
# Processing nyse:qsr for year 2018...
# Processing nyse:qsr for year 2019...
# Processing nyse:qsr for year 2020...
# Processing nyse:qsr for year 2021...
# Processing nyse:qsr for year 2022...
# Processing nyse:wwe for year 2017...
# Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Your max_length is set to 200, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 200, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 200, but your input_length is only 142. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 200, but your input_length is only 36. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 142, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 142, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 142, but your input_length is only 129. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 142, but your input_length is only 31. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 200, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Processing nyse:wwe for year 2018...
# Your max_length is set to 200, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 200, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 200, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 200, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 200, but your input_length is only 32. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 142, but your input_length is only 102. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Your max_length is set to 142, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 142, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 142, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 142, but your input_length is only 36. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 142, but your input_length is only 29. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 200, but your input_length is only 187. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Processing nyse:wwe for year 2019...
# Your max_length is set to 200, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 200, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 200, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 200, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 142, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 142, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 142, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 142, but your input_length is only 140. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# Your max_length is set to 142, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 142, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 200, but your input_length is only 25. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Processing nyse:wwe for year 2020...
# Your max_length is set to 200, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 200, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 200, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 200, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 200, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 142, but your input_length is only 24. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 142, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 142, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 142, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 142, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 142, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 200, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Processing nyse:wwe for year 2021...
# Your max_length is set to 200, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# Your max_length is set to 200, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 200, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 200, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 200, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 200, but your input_length is only 35. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Your max_length is set to 142, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 142, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 142, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 142, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 142, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 142, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 200, but your input_length is only 176. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
# Processing nyse:wwe for year 2022...
# Your max_length is set to 200, but your input_length is only 51. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 200, but your input_length is only 114. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 200, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 200, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 200, but your input_length is only 158. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
# Your max_length is set to 200, but your input_length is only 156. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# Your max_length is set to 200, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 200, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 200, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 142, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 142, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 142, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 142, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 142, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 142, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 142, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Analysis complete.

# %%
# create dataframe for results
if analysis_results:
    results_df = pd.DataFrame(analysis_results)
else:
    results_df = pd.DataFrame()

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
results_df
# Out:
#           Ticker  Year                                    PROs_Summary_T5  \
# 0    nasdaq:aapl  2017  Direct Management: good environment, almost ev...
# 1    nasdaq:aapl  2018  Direct Management: Sehr gute Bezahlung im Verg...
# 2    nasdaq:aapl  2019  Direct Management: otima experiencia, pessoas ...
# 3    nasdaq:aapl  2020  Direct Management: molti telefoni anche a bass...
# 4    nasdaq:aapl  2021  Direct Management: a gran empresa que cuida de...
# 5    nasdaq:aapl  2022  Direct Management: the people you meet and get...
# 6    nasdaq:adsk  2017  Direct Management: nice salary, good training,...
# 7    nasdaq:adsk  2018  Direct Management: great colleagues - encourag...
# 8    nasdaq:adsk  2019  Direct Management: empresa que cuida muco de s...
# 9    nasdaq:adsk  2020  Direct Management: a lot of recognition is giv...
# 10   nasdaq:adsk  2021  Direct Management: Grandes profesionales dispu...
# 11   nasdaq:adsk  2022  Direct Management: autodesk supports well on w...
# 12   nasdaq:amzn  2017  Direct Management: Zappos is a very fun place ...
# 13   nasdaq:amzn  2018  Direct Management: great health insurance, bes...
# 14   nasdaq:amzn  2019  Direct Management: Gute Bezahlung, Getränke ko...
# 15   nasdaq:amzn  2020  Direct Management: melhor empresa no rama mpre...
# 16   nasdaq:amzn  2021  Direct Management: buoni pasto, bei colleghi e...
# 17   nasdaq:amzn  2022  Direct Management: despite horror stories, rea...
# 18   nasdaq:cprt  2017  Direct Management: a company that values famil...
# 19   nasdaq:cprt  2018  Direct Management: copart offers training in m...
# 20   nasdaq:cprt  2019  Direct Management: nice company to work for an...
# 21   nasdaq:cprt  2020  Direct Management: been in Copart for 6 months...
# 22   nasdaq:cprt  2021  Direct Management: the people here are amazing...
# 23   nasdaq:cprt  2022  Direct Management: good culture with great lea...
# 24   nasdaq:csgp  2017  Direct Management: the salary is good for an o...
# 25   nasdaq:csgp  2018  Direct Management: everyone at the London offi...
# 26   nasdaq:csgp  2019  Direct Management: CoStar has a strong product...
# 27   nasdaq:csgp  2020  Direct Management: i've worked at Costar with ...
# 28   nasdaq:csgp  2021  Direct Management: great Commision Paid Leave ...
# 29   nasdaq:csgp  2022  Direct Management: the pay is pretty good and ...
# 30    nasdaq:fox  2018  Direct Management: the crew I worked with was ...
# 31    nasdaq:fox  2019  Direct Management: a well respected company an...
# 32    nasdaq:fox  2020  Direct Management: the money is good and peopl...
# 33    nasdaq:fox  2021  Direct Management: great company Nice employee...
# 34    nasdaq:fox  2022  Direct Management: - Great, homogeneous Chines...
# 35   nasdaq:goog  2017  Direct Management: -Being part of a small team...
# 36   nasdaq:goog  2018  Direct Management: flexible working environmen...
# 37   nasdaq:goog  2019  Direct Management: meu trabalho tinha muita re...
# 38   nasdaq:goog  2020  Direct Management: liberdade, Criatividade, Re...
# 39   nasdaq:goog  2021  Direct Management: good compensation, smart an...
# 40   nasdaq:goog  2022  Direct Management: great benefits and generall...
# 41   nasdaq:msft  2017  Direct Management: the process is solid (if no...
# 42   nasdaq:msft  2018  Direct Management: a very well organised inter...
# 43   nasdaq:msft  2019  Direct Management: great company culture, good...
# 44   nasdaq:msft  2020  Direct Management: Salaries alto end una empre...
# 45   nasdaq:msft  2021  Direct Management: microsoft befefit includes ...
# 46   nasdaq:msft  2022  Direct Management: the company has diversity, ...
# 47    nasdaq:nws  2017  Direct Management: staff restaurant is 5-star ...
# 48    nasdaq:nws  2018  Direct Management: great environment but not a...
# 49    nasdaq:nws  2019  Direct Management: there is an equal number of...
# 50    nasdaq:nws  2020  Direct Management: covid has provided excellen...
# 51    nasdaq:nws  2021  Direct Management: my team really had a strong...
# 52    nasdaq:nws  2022  Direct Management: the best company to work wi...
# 53   nasdaq:sbux  2017  Direct Management: the 30% off Starbucks is re...
# 54   nasdaq:sbux  2018  Direct Management: employees got a 40% discoun...
# 55   nasdaq:sbux  2019  Direct Management: plano de carreira para os j...
# 56   nasdaq:sbux  2020  Direct Management: man kann da lernen, wie man...
# 57   nasdaq:sbux  2021  Direct Management: trabalhistas e fornece supo...
# 58   nasdaq:sbux  2022  Direct Management: good pay Good benefits Easy...
# 59    nasdaq:wtw  2017  Direct Management: CEO Peter is/was eccentric ...
# 60    nasdaq:wtw  2018  Direct Management: a carga horária de 35h sema...
# 61    nasdaq:wtw  2019  Direct Management: the company is very flexibl...
# 62    nasdaq:wtw  2020  Direct Management: salaris werkstudent/ makkel...
# 63    nasdaq:wtw  2021  Direct Management: ontwikkeling van junior tot...
# 64    nasdaq:wtw  2022  Direct Management: Willis Towers Watson is a l...
# 65      nasdaq:z  2017  Direct Management: Trulia has a great equity a...
# 66      nasdaq:z  2018  Direct Management: the people you'll work with...
# 67      nasdaq:z  2019  Direct Management: employees are typically fri...
# 68      nasdaq:z  2020  Direct Management: good compensation Company d...
# 69      nasdaq:z  2021  Direct Management: great benefits for parents,...
# 70      nasdaq:z  2022  Direct Management: great benefits for the posi...
# 71      nyse:acn  2017  Direct Management: muy amigable y con buen cli...
# 72      nyse:acn  2018  Direct Management: great supervisors, Supporti...
# 73      nyse:acn  2019  Direct Management: es werden so gut wie alle B...
# 74      nyse:acn  2020  Direct Management: buena empresa, con crecimie...
# 75      nyse:acn  2021  Direct Management: colleghi gentili e tanti di...
# 76      nyse:acn  2022  Direct Management: good pay and work life bala...
# 77      nyse:bki  2017  Direct Management: good company to work for Em...
# 78      nyse:bki  2018  Direct Management: the people you work with ar...
# 79      nyse:bki  2019  Direct Management: small company, president wh...
# 80      nyse:bki  2020  Direct Management: Optimal Blue is a growing c...
# 81      nyse:bki  2021  Direct Management: flexible work hours, hands ...
# 82      nyse:bki  2022  Direct Management: i have been working here fo...
# 83      nyse:dis  2017  Direct Management: free top -of-the-line healt...
# 84      nyse:dis  2018  Direct Management: the design team is full of ...
# 85      nyse:dis  2019  Direct Management: el trato al empleado en gen...
# 86      nyse:dis  2020  Direct Management: sueldo competitivo Horario ...
# 87      nyse:dis  2021  Direct Management: experiência de trabalho inc...
# 88      nyse:dis  2022  Direct Management: the pros are always based o...
# 89      nyse:nke  2017  Direct Management: great employee discount, fu...
# 90      nyse:nke  2018  Direct Management: the convivencia es buena po...
# 91      nyse:nke  2019  Direct Management: muy buenos descuentos de em...
# 92      nyse:nke  2020  Direct Management: tolles Unternehmen, nette M...
# 93      nyse:nke  2021  Direct Management: a empresa increble que te p...
# 94      nyse:nke  2022  Direct Management: great discounts, loved help...
# 95      nyse:pfe  2017  Direct Management: work life balance, good foo...
# 96      nyse:pfe  2018  Direct Management: great people and small enou...
# 97      nyse:pfe  2019  Direct Management: tolle Atmosphäre, tolles Ge...
# 98      nyse:pfe  2020  Direct Management: timos benefcios principalme...
# 99      nyse:pfe  2021  Direct Management: se trabaja muy comodo hay e...
# 100     nyse:pfe  2022  Direct Management: good work life balance, goo...
# 101     nyse:qsr  2017  Direct Management: you're able to learn a lot ...
# 102     nyse:qsr  2018  Direct Management: food is free for employees ...
# 103     nyse:qsr  2019  Direct Management: trabajador aprender mucho d...
# 104     nyse:qsr  2020  Direct Management: molto comprensivi e che cer...
# 105     nyse:qsr  2021  Direct Management: trabajo en equipo y buen pr...
# 106     nyse:qsr  2022  Direct Management: manager was very nice to me...
# 107     nyse:wwe  2017  Direct Management: everyone that works here is...
# 108     nyse:wwe  2018  Direct Management: Vince McMahon is awesome, I...
# 109     nyse:wwe  2019  Direct Management: the entire department is fu...
# 110     nyse:wwe  2020  Direct Management: pay and some people were gr...
# 111     nyse:wwe  2021  Direct Management: great growth opportunity Gr...
# 112     nyse:wwe  2022  Direct Management: good good food wood Hello. ...
#
#                                        CONs_Summary_T5  \
# 0    Direct Management: trabalha-se 44h semanais o ...
# 1    Direct Management: midlevel managers believe i...
# 2    Direct Management: management tendiert dazu ma...
# 3    Direct Management: nog niet opgemerkt, denk ni...
# 4    Direct Management: eu acho que o salario dever...
# 5    Direct Management: contract workers are kept s...
# 6    Direct Management: the company retrenched empl...
# 7    Direct Management: the role of people manager ...
# 8    Direct Management: good people leave and peopl...
# 9    Direct Management: ninguna hasta el da de hoy ...
# 10   Direct Management: the team became increasingl...
# 11   Direct Management: managers and directors are ...
# 12   Direct Management: some minor company reorgani...
# 13   Direct Management: the whole employee happines...
# 14   Direct Management: a carreira interna depende ...
# 15   Direct Management: avrei lavorato tranquillame...
# 16   Direct Management: management is a rollercoast...
# 17   Direct Management: no premium for working in c...
# 18   Direct Management: management goes to sleep on...
# 19   Direct Management: qualquer erro do funcionári...
# 20   Direct Management: a gesto no separa o profiss...
# 21   Direct Management: management, favoritism, bul...
# 22   Direct Management: no cons found till date, ev...
# 23   Direct Management: peor es unas de las compani...
# 24   Direct Management: a company culture that sing...
# 25   Direct Management: management has a habit of b...
# 26   Direct Management: a colleague of mine is leav...
# 27   Direct Management: VP &amp; SVP micromanage th...
# 28   Direct Management: the company has strict no w...
# 29   Direct Management: the internal customer relat...
# 30   Direct Management: carga de trabajo se puede j...
# 31   Direct Management: nao tenho contras ,Acredito...
# 32   Direct Management: management is hard to meet ...
# 33   Direct Management: some teams have toxic leade...
# 34   Direct Management: the benefit in China is not...
# 35   Direct Management: you are doing jobs usually ...
# 36   Direct Management: poor management, poor commu...
# 37   Direct Management: a lack of positive feedback...
# 38   Direct Management: lower management does not k...
# 39   Direct Management: Production Management has r...
# 40   Direct Management: staff is very good hey. don...
# 41   Direct Management: no cons that i know about. ...
# 42   Direct Management: a lot of information is bei...
# 43   Direct Management: a fair amount of nepotism c...
# 44   Direct Management: estar em uma subsidiária to...
# 45   Direct Management: poco balance vida laboral y...
# 46   Direct Management: no tengo ninguna desventaja...
# 47   Direct Management: bad hires, poor management,...
# 48   Direct Management: management are poor at deal...
# 49   Direct Management: there are some union positi...
# 50   Direct Management: don't expect managers to be...
# 51   Direct Management: no concerns. everything is ...
# 52   Direct Management: managers micromanage No pat...
# 53   Direct Management: low pay for what you're doi...
# 54   Direct Management: pressure from managers to m...
# 55   Direct Management: poco sueldo y bastante pres...
# 56   Direct Management: een beetje chaotisch als he...
# 57   Direct Management: aucune valeur morale, que c...
# 58   Direct Management: starbucks doesn't pay enoug...
# 59   Direct Management: some senior management coul...
# 60   Direct Management: inexperienced manager stopp...
# 61   Direct Management: the benefits are not bad, b...
# 62   Direct Management: ser zijn geen minpunten te ...
# 63   Direct Management: the Personalmanagement war ...
# 64   Direct Management: the company uses offshore s...
# 65   Direct Management: managers are unethical liar...
# 66   Direct Management: the culture has more impost...
# 67   Direct Management: management doesn't care abo...
# 68   Direct Management: poor leadership by my direc...
# 69   Direct Management: micro manager very cut thro...
# 70   Direct Management: a lack of strong leadership...
# 71   Direct Management: management needs to be more...
# 72   Direct Management: o tamanho da empresa diminu...
# 73   Direct Management: a mi parece malos sueldos, ...
# 74   Direct Management: las responsabilidades estén...
# 75   Direct Management: Salario minimo Mucha gente ...
# 76   Direct Management: despite signing a multi-yea...
# 77   Direct Management: management and executive te...
# 78   Direct Management: the CEO/Owner is overly fru...
# 79   Direct Management: the department is being mic...
# 80   Direct Management: many people fleeing LoanCar...
# 81   Direct Management: training was terrible, many...
# 82   Direct Management: training for new hires was ...
# 83   Direct Management: cancels insurance without i...
# 84   Direct Management: department management can b...
# 85   Direct Management: muitas horas de trabalho de...
# 86   Direct Management: carga laboral desbalanceada...
# 87   Direct Management: nenhum ponto negativo com m...
# 88   Direct Management: the positive impact usually...
# 89   Direct Management: no tem pontos negativos, é ...
# 90   Direct Management: solo un dia de descanso que...
# 91   Direct Management: no observe grandes ventajas...
# 92   Direct Management: el trabajo pero igual incre...
# 93   Direct Management: weinig door groei mogelijkh...
# 94   Direct Management: management de relation chez...
# 95   Direct Management: policies are not implemente...
# 96   Direct Management: management/ valeurs/ qualit...
# 97   Direct Management: directores junior, promueve...
# 98   Direct Management: mucha carga laboral Jornada...
# 99   Direct Management: equilibrio vida trabajo no ...
# 100  Direct Management: I suffered bullying (racial...
# 101  Direct Management: acredito nao possuir pontos...
# 102  Direct Management: the higher you go up the ma...
# 103  Direct Management: falta de reconhecimento pro...
# 104  Direct Management: manager un peu irrespectueu...
# 105  Direct Management: underpaid, poor management ...
# 106  Direct Management: the level of nepotism is ra...
# 107  Direct Management: Depending on your departmen...
# 108  Direct Management: managers are not nice. most...
# 109  Direct Management: no bonuses Takes a while to...
# 110  Direct Management: management is utterly incom...
# 111  Direct Management: senior management is a joke...
# 112  Direct Management: management on every level i...
#
#                                      PROs_Summary_BART  \
# 0    Direct Management: Good environment, almost ev...
# 1    Direct Management: Stable leadership, great wo...
# 2    Direct Management: Gutes Gehalt- Gute Arbeitsb...
# 3    Direct Management: Great product (but needs TL...
# 4    Direct Management: The company offers good ben...
# 5    Direct Management: Great work environment and ...
# 6    Direct Management: Good benefits, flexibility,...
# 7    Direct Management: Good pay, good work life ba...
# 8    Direct Management: Work life balance. Location...
# 9    Direct Management: The people are just amazing...
# 10   Direct Management: C staff took great care of ...
# 11   Direct Management: Autodesk has a great cultur...
# 12   Direct Management: The Zappos internship is an...
# 13   Direct Management: Some very caring people, wo...
# 14   Direct Management: Good team with longevity an...
# 15   Direct Management: The company is a very nice ...
# 16   Direct Management: Verein. support, collegues,...
# 17   Direct Management: Work life balance, Job secu...
# 18   Direct Management: Great company to work for. ...
# 19   Direct Management: Copart provides a very chal...
# 20   Direct Management: Good pay and great health b...
# 21   Direct Management: Copart is a wonderful compa...
# 22   Direct Management: This is my first job out of...
# 23   Direct Management: Good culture with Great lea...
# 24   Direct Management: Location, salary, people (s...
# 25   Direct Management: CoStar's London office is l...
# 26   Direct Management: CoStar has a strong product...
# 27   Direct Management: Costar pays it's sales empl...
# 28   Direct Management: CoStar does IT properly. Th...
# 29   Direct Management: The pay is pretty good. Dis...
# 30   Direct Management: Hands-on experience opportu...
# 31   Direct Management: Good people and technology....
# 32   Direct Management: I felt really valued as an ...
# 33   Direct Management: Good place for contract wor...
# 34   Direct Management: Great working environment a...
# 35   Direct Management: Google perks (onsite free c...
# 36   Direct Management: Flexible working environmen...
# 37   Direct Management: Google is great company and...
# 38   Direct Management: Perks, compensation, cultur...
# 39   Direct Management: Fantastic perks on campus. ...
# 40   Direct Management: Google is a great place to ...
# 41   Direct Management: The process is solid (if no...
# 42   Direct Management: Good work-life balance in s...
# 43   Direct Management: Great company culture, good...
# 44   Direct Management: Salaries alto end una empre...
# 45   Direct Management:  microsoft befefit includin...
# 46   Direct Management: Microsoft is an amazing com...
# 47   Direct Management: Great location directly opp...
# 48   Direct Management: Storyful is full of opportu...
# 49   Direct Management: Storyful has a strong cultu...
# 50   Direct Management: The Barcelona office is an ...
# 51   Direct Management: Good people, opportunities ...
# 52   Direct Management: Best company to work with s...
# 53   Direct Management: Good people, discount on te...
# 54   Direct Management: Employees got a 40% discoun...
# 55   Direct Management: Flexible, temps partiel, ma...
# 56   Direct Management: Great work environment! Nic...
# 57   Direct Management: Mi puesto actual es Supervi...
# 58   Direct Management: Good pay, good drinks, good...
# 59   Direct Management: Lots of young, intelligent ...
# 60   Direct Management: The company works as one P&...
# 61   Direct Management: The company is very flexibl...
# 62   Direct Management: Nombreux en tant que salari...
# 63   Direct Management: Empresa fornece diversos pr...
# 64   Direct Management: Willis Towers Watson is a l...
# 65   Direct Management: Trulia has a great equity a...
# 66   Direct Management: The company is great to wor...
# 67   Direct Management: The company really valued m...
# 68   Direct Management: Company doesn't seem evil, ...
# 69   Direct Management: Zillow has amazing benefits...
# 70   Direct Management: This job was a fantastic en...
# 71   Direct Management: Good employees, Good cultur...
# 72   Direct Management: Good salary, Good work envi...
# 73   Direct Management: Toller Arbeitgeber mit viel...
# 74   Direct Management: Gran trabajo en equipo, emp...
# 75   Direct Management: Experiencia laboral, bonos ...
# 76   Direct Management: Great pay and benefits. Lot...
# 77   Direct Management: Caring, fun and knowledgeab...
# 78   Direct Management: The people you work with ar...
# 79   Direct Management: Work life balance is amazin...
# 80   Direct Management: Optimal Blue is a growing c...
# 81   Direct Management: Flexible work hours, hands ...
# 82   Direct Management: Black Knight is a professio...
# 83   Direct Management: Free paid meal if you work ...
# 84   Direct Management: I had a great work/life bal...
# 85   Direct Management: As Guest Relations you get ...
# 86   Direct Management: The best part is the custom...
# 87   Direct Management: Gran ambiente laboral, exce...
# 88   Direct Management: Great team + good training ...
# 89   Direct Management: Nike is more like a family ...
# 90   Direct Management: Good pay rate and discounts...
# 91   Direct Management: Employee discount. Work lif...
# 92   Direct Management: Tolles Unternehmen, nette M...
# 93   Direct Management: Working on Virtasant is rea...
# 94   Direct Management: Great discount, loved helpi...
# 95   Direct Management: Work life balance. good pay...
# 96   Direct Management: Work/Life Balance. good wor...
# 97   Direct Management: Great training, superior pr...
# 98   Direct Management: Azienda leader con prodotti...
# 99   Direct Management: Take ownership of your own ...
# 100  Direct Management: Pfizer is a good place to w...
# 101  Direct Management: The restaurant was actually...
# 102  Direct Management: Food is free for employees ...
# 103  Direct Management: Es bueno y muy buena experi...
# 104  Direct Management: Ce job est très chaleureux ...
# 105  Direct Management: Teamwork Freundlichkeit Sau...
# 106  Direct Management: The experience was so terri...
# 107  Direct Management: Very professional and carin...
# 108  Direct Management: + Vince McMahon is awesome,...
# 109  Direct Management: The entire department is fu...
# 110  Direct Management: Pay and some people were gr...
# 111  Direct Management: Great management styles. Go...
# 112  Direct Management: Wrestling friends defending...
#
#                                      CONs_Summary_BART
# 0    Direct Management: The CEO and CFO of finance ...
# 1    Direct Management: Midlevel managers are terri...
# 2    Direct Management: The senior managers have no...
# 3    Direct Management: Cult and brain washing cult...
# 4    Direct Management: There seemed to be some fav...
# 5    Direct Management: It's perfect and the owners...
# 6    Direct Management: India team is going through...
# 7    Direct Management: HR is just there to help ma...
# 8    Direct Management: Good people leave and Peopl...
# 9    Direct Management: Autodesk is slow to innovat...
# 10   Direct Management: Local. focus not on people ...
# 11   Direct Management: Autodesk claims to promote ...
# 12   Direct Management: There's really nothing bad ...
# 13   Direct Management: Nepotism runs rampant at Za...
# 14   Direct Management: If one is in a department c...
# 15   Direct Management: Turni, work-life balance, g...
# 16   Direct Management: Horrible management, manage...
# 17   Direct Management: Rude, unsupportive supervis...
# 18   Direct Management: I worked at Copart for 14 y...
# 19   Direct Management: Management blame everything...
# 20   Direct Management: The company is very old fas...
# 21   Direct Management: Yard quality is atrocious a...
# 22   Direct Management: So far enjoyed working with...
# 23   Direct Management: Pay is mid, management is p...
# 24   Direct Management: Company culture that single...
# 25   Direct Management: Working hours, salary and w...
# 26   Direct Management: CoStar is not as great to t...
# 27   Direct Management: The culture is very strict ...
# 28   Direct Management: CEO has strict no work from...
# 29   Direct Management: Work itself is tedious, but...
# 30   Direct Management: There were no cons at this ...
# 31   Direct Management: Office is at Artarmon, so i...
# 32   Direct Management:  internship is so short, wi...
# 33   Direct Management: Tubi was acquired by Disney...
# 34   Direct Management: The benefit in China is not...
# 35   Direct Management: Lack senior staff, hires to...
# 36   Direct Management: Small company but nice envi...
# 37   Direct Management: Hiring process post interns...
# 38   Direct Management: Work-life balance is bad ev...
# 39   Direct Management: Production Management has r...
# 40   Direct Management: Location Manager Growth in ...
# 41   Direct Management: No cons that i know about. ...
# 42   Direct Management: Get good CRM and force ever...
# 43   Direct Management: The employee is not importa...
# 44   Direct Management: Crescimento de carreira pod...
# 45   Direct Management: Salario regular, trabajo re...
# 46   Direct Management: Employees have to live for ...
# 47   Direct Management: Communication between depar...
# 48   Direct Management: Low salary, do not value em...
# 49   Direct Management: No career progression line,...
# 50   Direct Management: Toxic environment, need to ...
# 51   Direct Management: Work life is good. No conce...
# 52   Direct Management: Incompetent supervisors oft...
# 53   Direct Management: Lack of training, passive a...
# 54   Direct Management: Small firms may have fewer ...
# 55   Direct Management: Viele Shift Manager, (Assis...
# 56   Direct Management: Howard Schultz n'y est plus...
# 57   Direct Management: Planning rotatif sans aucun...
# 58   Direct Management: No such thing as work-life ...
# 59   Direct Management: Some senior management coul...
# 60   Direct Management: Worthless upper management ...
# 61   Direct Management: The benefits are not bad, b...
# 62   Direct Management: Lack of emphasis on persona...
# 63   Direct Management: Personalmanagement war zu m...
# 64   Direct Management: The company is very heavily...
# 65   Direct Management: HR gave too much leniency t...
# 66   Direct Management: Work from home policy is Te...
# 67   Direct Management: Employees were gatekeepers ...
# 68   Direct Management: Company seems very far behi...
# 69   Direct Management: "I'll be looking for other ...
# 70   Direct Management: A lot of ambiguity, and lea...
# 71   Direct Management: Most women are given little...
# 72   Direct Management: O tamanho da empresa diminu...
# 73   Direct Management: A mi parece malos sueldos, ...
# 74   Direct Management: Las posibilidades de crecim...
# 75   Direct Management: No se puede trabajar desde ...
# 76   Direct Management: Great company, but there's ...
# 77   Direct Management: New management and executiv...
# 78   Direct Management: NL doesn't own/operate anyw...
# 79   Direct Management: Toxic and cutthroat environ...
# 80   Direct Management: Managers not equipped to le...
# 81   Direct Management: The way a company trains yo...
# 82   Direct Management: Company went under so mass ...
# 83   Direct Management: Hotel is not unionized so t...
# 84   Direct Management: Bad management, hard to mov...
# 85   Direct Management: Managers très strictes, hau...
# 86   Direct Management: Los empleados están muy ori...
# 87   Direct Management: Nenhum ponto negativo a dec...
# 88   Direct Management: The people in the operation...
# 89   Direct Management: Nao apresenta ao meu ver ne...
# 90   Direct Management: No hay capacitaciones.. Het...
# 91   Direct Management: Some managers are undoubted...
# 92   Direct Management: Manejo de presupuestos. Car...
# 93   Direct Management: Matrix org complex relaties...
# 94   Direct Management: No cons for this job. Horri...
# 95   Direct Management: The pay is below par. Benef...
# 96   Direct Management: Company- They say they put ...
# 97   Direct Management: Gerentes y Directores a niv...
# 98   Direct Management: Bad management and no work ...
# 99   Direct Management: Pay is far below industry s...
# 100  Direct Management: Could improve compensation ...
# 101  Direct Management: Almost all the staff are fo...
# 102  Direct Management: Management and the customer...
# 103  Direct Management: Falta de reconhecimento pro...
# 104  Direct Management: Jeder darf mal.. poco equil...
# 105  Direct Management: Underpaid, poor management ...
# 106  Direct Management: Pay, location, lack of uppe...
# 107  Direct Management: There is no downside to wor...
# 108  Direct Management: Michael Luisi was the worst...
# 109  Direct Management: Knew two women who felt har...
# 110  Direct Management: Senior management is challe...
# 111  Direct Management: Randy orton the viper puts ...
# 112  Direct Management: Senior management does not ...

# %%
def get_summary_for_company(ticker_symbol, results_dataframe):
    company_report = results_dataframe[results_dataframe['Ticker'] == ticker_symbol].copy()
    company_report.sort_values('Year', inplace=True)
    return company_report


ticker_to_find = 'nasdaq:aapl'
company_summary = get_summary_for_company(ticker_to_find, results_df)

print(f"\n\n--- Comparing BART and T5 {ticker_to_find} ---")


# display full text
for index, row in company_summary.iterrows():
    print(f"\n{'='*15} Year: {row['Year']} {'='*15}")

    # PROs
    print("\n--- PROs ---")
    print("\nT5 Summary:")
    print(str(row['PROs_Summary_T5']).replace(". ", ".\n"))
    print("\nBART Summary:")
    print(str(row['PROs_Summary_BART']).replace(". ", ".\n"))

    # CONs
    print("\n--- CONs ---")
    print("\nT5 Summary:")
    print(str(row['CONs_Summary_T5']).replace(". ", ".\n"))
    print("\nBART Summary:")
    print(str(row['CONs_Summary_BART']).replace(". ", ".\n"))
    print("-" * 40)
# Out:
# --- Comparison Report for nasdaq:aapl ---
#
# =============== Year: 2017 ===============
#
# --- PROs ---
#
# T5 Summary:
# Direct Management: good environment, almost everybody is nice, can work independently .
# partweise nettes Team Interessante Kunden Benefits sind nicht schlecht Relativ entspannte Arbeit Null Entwicklungsmöglichkeiten Organizational Alignment: a cultura é super forte e você melhora como ser humano .
# uma empresa muito conceituada Engagement: apple heeft het work-life balance principe volledig geimplementeerd .
# krijgen gemiddeld 9 weken vakantie Innovation: a great environment with vibrant brilliant people .
# nette Kollegen, tolles Produkt, apple-Tochter, zahlen gut .
# Organizational Effectiveness: otimos benefcios e ótimo salário.
# Ambiente bem mantido pela empresa .
# Fun Emotional Connection: timo ambiente de trabalho, funcionários que prezam pela cultura da empresa e sempre pelo melh Extrinsic Rewards: the student gets all benefits as a full-timer, very good people .
# good benefits like gym and medical.
# job security wages are ok the system makes you write 5 pros the system
#
# BART Summary:
# Direct Management: Good environment, almost everybody is nice, can work independently.
# Great co-worker and immediate manager.
# Excellent health benefits..
# None.
# Organizational Alignment: No hay mucha presión por parte of los ejecutivos, el sueldo es muy bueno.
# O mais legal na Apple é that a Engagement: Apple heeft het work-life balance principe volledig geimplementeerd.
# Medewerkers krijgen gemiddeld 9 weken Innovation: A great environment with vibrant brilliant people.
# Opportunity to learn from experienced engineers.
# Rain or shine there was always a positive vibe from everyone.
# Organizational Effectiveness: Pionera en su rubro, creadora de rubros, capacidad de modificar hábitos a nivel global.
# Great, energetic, and intelligent team Emotional Connection: Apple Retail is one of best environments to meet incredible people and to enhance interpersonal skills.
# It's a place where you feel at home since day one.
# The comfort of working from home.
# Re Extrinsic Rewards: Siblins are not considered family and conpany does not consider them as such in their policies.
# Gym, Cafe Macs, free goodies, benefits!!!.
# nothing to be good for
#
# --- CONs ---
#
# T5 Summary:
# Direct Management: trabalha-se 44h semanais o que é extremamente puxado pra quem no está acostuma Organizational Alignment: el secretsimo que caracteriza a la compaa es un punto negativo, as como algunas cosas en Engagement: jullie doen het perfect zijn geen enkele minpunten aanwezig .
# die Arbeitszeiten sind viel zu lange im Voraus geplant Innovation: affluence en magasin vraiment difficile à gérer par moment Perspectives d'evolution très limitées Salaire lamentable .
# Il faut être ouvert aux changements Organizational Effectiveness: trabalhei ainda engatinhava no Brasil .
# he foi uma experiência fantástica! .
# Emotional Connection: it can be a stressful job at times, though the team is always there for support .
# it can feel slow and within the space of 5 years you are likely to hit the ceiling of your Extrinsic Rewards: food is 9 dollars per meal, even soda is sold (1$ per can), gym is not free...
# shame for such a big company which is a part of one of the wealthiest
#
# BART Summary:
# Direct Management: The CEO and CFO of finance are the worst.
# No room to grow, upper management is ignorant to day to day issues.
# Executives are horrible and egotistical.
# The finance Organizational Alignment: "Fuerte desgaste por un liderazgo pronunciado en una multiplicidad of medios y regiones" "Los clientes no suelen ap Engagement: Work can be intense sometimes.
# Er zijn geen enkele minpunten aanwezig, jullie doen het perfect.
# Die Arbeitszeiten Innovation: Apple store d'opera, beaucoup of travail and manque of communication clair of the part of the direction.
# Trabalho estressante e intenso Organizational Effectiveness: Working in the marketing department is like going back to the worst high school you can imagine.
# The leadership is a boys club and complete joke.
# Money is so completely mismanaged that Apple would be Emotional Connection: It can be a stressful job at times, though the team is always there for support.
# Career progression is slow the options are unclear.
# Silo'd workplace and quieter work environment.
# Extrinsic Rewards: Food is 9 dollars per meal, even soda is sold (1$ per can), gym is not free...
# shame for such a big company which is a part of one of the wealthiest companies
# ----------------------------------------
#
# =============== Year: 2018 ===============
#
# --- PROs ---
#
# T5 Summary:
# Direct Management: Sehr gute Bezahlung im Vergleich zu anderen Einzelhandelsunternehmen .
# good perks and facilities, respectable remuneration.
# perfect company lots of benefits .
# Organizational Alignment: empresa com ótimos benefcios, acima da média para a maioria do que é oferecido no  Engagement: apple is ein richtig guter Arbeitgeber , hier kann man sich vorstellen eine sehr lange Zeit zu bleiben .
# Innovation: me gustan los productos apple y poder probar las nuevas innovaciones mundiales no tiene precio ademas pod Organizational Effectiveness: bon salaire - super culture d'entreprise (inclusion et diversité) - management au top - pas mal d’evenement, la boite sait prendre soin Emotional Connection: trabalhar provides with transport and other necessitites .
# the company provides with with transport, transportation and others .
# you can buy a phone for 100 euro .
# Extrinsic Rewards: tickets restaurant, 13ème mois, CE avantageux, DIF généreux, congés, réductions des prix des produits de l’entreprise, très bonne mutuelle peu
#
# BART Summary:
# Direct Management: Stable leadership, great work/life balance, fantastic team.
# Good perks and facilities, respectable remuneration.
# Lots of benefits.
# nice environment and great people.
# Organizational Alignment: I love the job.
#  It was a great atmosphere.
#  We delivered excellent service..
# Very stable company.
# A CEO with good values.
# Engagement: Great employees and work culture.
# The employees are truly talented!.
# Apple ist ein richtig guter Arbeitgeber.
# You can always get along with the people you work with Innovation: Loved the products Beats was selling and it is a cool brand that many can relate to.
# Apple benefits, stable and small company environment.
# Organizational Effectiveness: Solid people, strong leadership.
# Good team, great office with good facilities.
# - flache Hierarchie.
# - offene Kultur und Feedbackkultur.
# Emotional Connection: Great pay, great benefits.
# Lots of cool people to work with.
# Great atmosphere, loads of support.
# You work from home and it is easy money.
# Because it’s a very Extrinsic Rewards: Tickets restaurant, 13ème mois, CE avantageux, DIF généreux, congés, réductions des prix des produits de l�
#
# --- CONs ---
#
# T5 Summary:
# Direct Management: midlevel managers believe in leading by fear! communication is terrible .
# if issues are brought up, either you are ignored and are always quick to say you are wrong before looking into the issue  Organizational Alignment: a linha da empresa Desenvolver projetos de forma coerente Necessidade de estar sempre atualizado  Engagement: no encuentro ningun punto negativo a la empresa Apple .
# no seu dia de folga nao ter Innovation: Très mauvaise direction, ambiance variante selon les magasins, peu d’événements, hiérarchie à l’américaine mais exercée  Organizational Effectiveness: many VPs think they are experts at everything while, in the reality, they are not even good at their own areas .
# FileMaker sorely lacked a CMO and Emotional Connection: stress, Zeitdruck, stressige Kunden, schwierige Kunden, Druck.
# Sehr viele Kunden und damit Stress.
# Alles sehr Anonym Hohe Fluktuation bei den Mitarbeitern.
# Extrinsic Rewards: the salary was not as good as antispicated .
# part-timers end up working full-time hours but still maintain that title .
# the admin only deny and don’t
#
# BART Summary:
# Direct Management: Midlevel managers are terrible! Due to their LACK of experience, they believe in leading by fear! Communication is terrible! Changes are constant because of their inability to make good business decisions.
# Organizational Alignment: Don't understand regional (country) differences, always wanted to do things the way they work in the US.
# No trust.
# Every organization for themselves.
# Stuck in 1998.
# No support to Engagement: Não le encuentro ningun punto negativo a la empresa Apple.
# No seu dia de folga nao terá vontade de Innovation: Process and change was slow, many products were outdated on the showroom and many malfunctions.
# Très mauvais salaire pouce rouge.
# not many chance to Organizational Effectiveness: Many of the VPs think they are experts at everything while, in the reality, they are not even good at their own areas.
# They treat agencies horribly, giving them little planning time and Emotional Connection: Stress can be unbearable and you need to find a balance because the benefits are amazing.
# Can feel like you aren’t contributing as the work gets done if you’re there Extrinsic Rewards: The pay could have been better.
# The admin only deny and don’t care.
# They’re there to oppress you.
# Their goal is profit and going further up.
# Only want
# ----------------------------------------
#
# =============== Year: 2019 ===============
#
# --- PROs ---
#
# T5 Summary:
# Direct Management: otima experiencia, pessoas boas, om salario, san francisco .
# ottawa,  Organizational Alignment: Tecnologia avançada para o sistema atual .
# humana, parceria, bom pagamento, amizades, carr Engagement: good hourly pay, amazing employer benefits as an LGBT individual .
# great stock options (see cons), regular employee surveys .
# good atmosphere and buzz Everyone is really friendly and helpful .
# Innovation: Mooie producten aardige mensen groot bedrijf ik heb hier nooit gewerkt .
# top bedijf met Organizational Effectiveness: independencia, Sueldo, Horarios, Capacitaciones, Ambiente Laboral .
# benefcios so maravilhosos  Emotional Connection: muitos benefcios, empresa realmente cuida de você e da sua carreira .
# bon salaire et Extrinsic Rewards: benefits are just new for 2020 and are better than ever but still, we need to pay the bus, food, and doctors for a company that earns 60B dollars in revenue in 2019
#
# BART Summary:
# Direct Management: Gutes Gehalt- Gute Arbeitsbedingungen - Gut "Work-life" balance.
# Firmenphilosophie, Kollegen, Kunden, Geh Organizational Alignment: Good for people interested in Operations/ Business Ops roles.
# Nice work environment and nice work while doing localisation testing.great set schedule (no changes for 4-6 months) Able to help Engagement: Flexible hours, great stock options, regular employee surveys.
# Great discount for the products and awesome team/work environment.
# Great pay and benefits.
# Innovation: Apple is the world's largest computer maker.
# The company is based in Cupertino, California.
# Its products are sold around the world.
# Organizational Effectiveness: O salário é acima da média de varejo.
# Os benefícios são maravilhosos.
# Time bastante preocupado Emotional Connection: Great benefits, work hours, social.
# Beats people are really open minded.
# They want to hear you whatever issue you have.
# You are at home so no commuting.
# Tuition Reimburse Extrinsic Rewards: Benefits, Sick pay, Holiday allowance, Discounts.
# Most challenging platform to work and show our abilities.
# Good benefits package, tuition reimbursement for college students.
#
# --- CONs ---
#
# T5 Summary:
# Direct Management: management tendiert dazu manchmal nach Nasenprinzip zu entscheiden .
# mehr Absprache untereinander.
# Sonst kein Kontra .
# half of the managers in the software group are clueless Organizational Alignment: empresa no consegue aplicar no Brasil a cultura de procedimentos que l'on peut se sentir comme un numéro .
# Engagement: the culture is the most important factor .
# our store had a "All for 1 and 1 for All" mindset .
# if they not pushing the standard and hiring a standard your culture Innovation: veel verantwoordelijkheid ik werk hier niet en heb hier nooit gewerkt .
# een  Organizational Effectiveness: manager poco flessibili e molte volte non all’altezza del ruolo .
# un peu dommage la communication Emotional Connection: muita cobrança, muito trabalho operacional, isolating working from home .
# a lot of undermining phrases thrown around Extrinsic Rewards: carga horária inflexvel, gerencia sem experiência em tecnologia, falta de clar
#
# BART Summary:
# Direct Management: The senior managers have no idea what they are doing.
# Half of the managers in the software group are clueless.
# If you only do what are told and willing to earn below market salary, you Organizational Alignment: You will be required taking shuttles to all the meetings and you might not have access to the building you are going to.
# The customers you interact with can be really rude but you just Engagement: The culture is the most important factor.
# Our store had a "All for 1 and 1 for All" mindset.
# I work at another store and it was the total opposite.
# The store leader Innovation: Falta de promoción interna entre Retail y Corporate.
# Ik werk hier niet en heb hier nooit gewerkt.
# Keine Vorwürfe Organizational Effectiveness: Pressione alta, ritmo elevato, segretezza eccessiva.
# Manager poco flessibili e molte volte non all’alte Emotional Connection: Call center work doesn’t suit everyone, isolating working from home.
# Insane work hours, lots of travel.
# Can cause PTSD because of the constant complaints and focus on metrics.
# Extrinsic Rewards: The pay wasn't great, but the benefits helped to outweigh that.
# High expectation to always be on.
# Difficult to earn promotion.
# Raise, if you earn one, is tiny.
# ----------------------------------------
#
# =============== Year: 2020 ===============
#
# --- PROs ---
#
# T5 Summary:
# Direct Management: molti telefoni anche a basso prezzo.
# Buen salario, con dietas y complementos.
# Trabajo muy bien rem Organizational Alignment: azienda coerente e attenta alle esigenze dei dipendenti.
# Cultura, prestgio, valores, ambiente Engagement: benefits, Team, Image, Sauberkeit, Klimaanlage.
# Incredible employee satisfaction through benefits.
# Jeder kann hier Arbeiten, man wird sehr gut eingeschult.
# Großer Vorteil für jüngere Bewerber Innovation: rapidez y seriedad y buena calidad de producto è molto sviluppata .
# il team working, il time management  Organizational Effectiveness: sueldo prestaciones descuentos home office.
# velocità e gestione del tempo.
# Possibilità di carriera.
# Todo Emotional Connection: leuke mensen en doorgroei mogelijkheden .
# muito bom trabalhar em uma equipe como a Extrinsic Rewards: ik ben hier tevreden want ze betalen goed en zijn duidelijk .
# molti benefit aziendali
#
# BART Summary:
# Direct Management: Great product (but needs TLC).
# Still some good people left.
# Boss listens, has given me tons of lateral movement to work on projects i like.
# Fun culture, team members are awesome Organizational Alignment: This is a great place to meet new people and find out more about the company.
# The site is designed to help you find the right place to work.
# The company is based in Brazil and Engagement: In Apple everyone Cares about you ad a person.
# Benefits, Team, Image, Sauberkeit, Klimaanlage.
# Incredible employee satisfaction through benefits.
# Qualifikation Innovation: L’organizzazione dell’azienda dal punto di vista del Retail è molto sviluppata.
# Consente chiaramente di Organizational Effectiveness: Benefit, orari, puoi imparare molte cose ma non deve essere il lavoro della vita..
# Fijn Team Goede Vo Emotional Connection: Una gran experiencia tecnológica y de vida.
# Grande porta for o mercado de trabalho.
# Empresa com vivências Extrinsic Rewards: Good payment, international enviroment, many benefits.
# Esprit de famille entre collègues.
# Entreprise incroyable par ses valeurs et sa
#
# --- CONs ---
#
# T5 Summary:
# Direct Management: nog niet opgemerkt, denk niet dat er veel zijn.
# Liderança deficiente, mentalidade de culto Organizational Alignment: ninguna estoy siempre satisfecho con todo .
# Nessuno svantaggio da segnalare, si la Engagement: a typical callcenter job (stressful in busy times) Keine Kontras bisher in dem Job.
# Location, Druck, Mitarbeiter, Arbeitszeiten, Aufstiegschancen .
# Innovation: no há contras, é a apple, qualquer um trabalharia ai .
# no hay ninguna des Organizational Effectiveness: nessuno alcuni telefoni sono a un prezzo elevato .
# alto volumen de trabajo con el tiempo mu Emotional Connection: no tiene ninguna desventaja en mon absoluto .
# horas que tienes que trabajar en total.
# cultura muy Extrinsic Rewards: non ho trovato alcun svantaggio, ottima esperienza lavorativa .
# non ne stanno parole per
#
# BART Summary:
# Direct Management: Cult and brain washing culture is too much, it’s more like a cult somhow.
# Specialist has no future, the job duty is meaningless unless u are a big fan of Organizational Alignment: Ninguna estoy siempre satisfecho con todo.
# Estar alejado de los míos.
# Nessuno svantaggio da segnalare, si Engagement: Lack of work life balance..
# Low mobility inside the company..
# Takes too much time and attention.
# Busy weekends.
# No pto for part timers.
# Innovation: Apple is een groot bedrijf.
# Nada o apple n decepicona xiaomi fica no xinelo.
# No hay ninguna desventaja, Organizational Effectiveness: Poco desarrollo profesional, muy poca capacitación.
# nessuno alcuni telefoni sono a un prezzo elevato.
# Hor Emotional Connection: No tiene ninguna desventaja en mon absoluto.
# A volte puÙ essere frenetico e stressante.
# Soms stressvol wanneer Extrinsic Rewards: In italy there’ s a strange way to use meritocracy.
# You work hard and take on challenges.
# Pay could be better across all areas a.
# ----------------------------------------
#
# =============== Year: 2021 ===============
#
# --- PROs ---
#
# T5 Summary:
# Direct Management: a gran empresa que cuida de sus empleados y su satisfacción .
# te ayudan mucho y t Organizational Alignment: boa empresa, bom salario, boa equipe e dinamismo .
# empresa muito estruturada, ofer Engagement: empresa bem profissional com bastantes oportunidades de progresso .
# -Time flexible -As a first job experience it may be Innovation: o nvel executivo, molto tempo libero, turni piacevoli .
# dinheiro viagens poder fazer o Organizational Effectiveness: todo bien nada mal bien y no creo que pueda hacer el traslado.
# servizi molto buoni e mol Emotional Connection: a boa empresa para se trabalhar é muito diversificado, possui um bom networking e é pos Extrinsic Rewards: benefits ottimo ambiente di lavoro, buoni pasto, assicurazione sanitaria, fondo pensione .
# stipendi più
#
# BART Summary:
# Direct Management: The company offers good benefits for the employee.
# Stable work environment, nice colleagues.
# Cool Smart spannend neu Hallo.
# Organizational Alignment: Buen equipo, horario, jefes y salario.
# Muito aberta a ideias e apoio.
# Es muy flexible, y busca prog Engagement: Health insurance pays a part of gym's suscription.
# Great colleagues and manager.
# Apple is an awesome employer.
# Innovation: Empresa gigantesca e com foco enorme no cliente, praticamente uma faculdade em customer experience.
# Benefícios de nível Organizational Effectiveness: Todo bien nada mal bien y no creo that pueda hacer el traslado.
# servizi molto buoni e molto disponib Emotional Connection: Super recomendo a Apple a qualquer momento.
# Muito Legal de trabalhar la.
# Rendimento bom, experiência de vendas, network.
# Extrinsic Rewards: Pay, Career progression, Training, Good Benefits, Stock options.
# Benefits personali e per familiari.
# Molti veloce bella gradevole super.
# Motivante
#
# --- CONs ---
#
# T5 Summary:
# Direct Management: eu acho que o salario deveria ser maio e trbalahr menos .
# Nenhuma experiencia r Organizational Alignment: nessun vero svantaggio molto negativo durante lavoro .
# poca probabilidad de crecimiento dentro de la  Engagement: trabalho intenso, gestao pode ser melhorada, mal reconhecimento .
# benefits, work-balance, location, Hard to Innovation: no considero que tenga desventajas sino aspectos por mejorar .
# no do chance de efetivaç Organizational Effectiveness: ninguna realmente, a excepción de la localidad en la ciudad .
# Trabalho bem estressante por vezes Emotional Connection: trabalho muito, horário puxado, cansativo, is a trabajo tóxico Extrinsic Rewards: argentina is zwar sehr schön mit einer koolen Bevölkerung, aber wenn man jung und unerfahren ist, sollte man den Schritt auf die Insel zu wagen
#
# BART Summary:
# Direct Management: There seemed to be some favoritism with some employees.
# No hay ninguna desventaja.
# Son muy majos..
# no te permite desarrollarte como persona.
# Organizational Alignment: Eu não vejo nenhum aspecto ruim.
# Nessuno tutto ok davvero bello.
# non ci sono svantaggi presenti tut Engagement: The Abteilung ist noch sehr neu in Barcelona, daher gibt es bisher noch keine Aufstiegsmöglichkeiten Innovation: Muito exigente quanto a tarefas.
# Exige muita disposição e vontade de aprender.
# No hay desventaja al est Organizational Effectiveness: Mala paga, empleo,competencia etc pero muy buen trabajo.
# Horarios de centro comercial, fines de semana y dom Emotional Connection: Apple España es un cortijo.
# No hay mucha flexibilidad with los trabajadores.
# Jornada de trabalho cansativa e ext Extrinsic Rewards: Irland is zwar sehr schön mit einer koolen Bevölkerung, aber wenn man jung und unerfahren ist, soll
# ----------------------------------------
#
# =============== Year: 2022 ===============
#
# --- PROs ---
#
# T5 Summary:
# Direct Management: the people you meet and get to work with are great .
# good work life balance &amp; good pay.
# excellent management and working environment .
# great team good pay good discounts .
# Organizational Alignment: great company to work for, the nicest team ever.
# Diverse, lots of opportunities to do new things .
# good team and good progress towards something you want to do and grow further Engagement: good package, nice people, fun.
# Awesome people, great benefits, good pay.
# Fast paced and fun environment with great people.
# - Competitive pay; - Smart people to work with.
# Innovation: best team in the industry.
# super intelligent founders.
# Happy to be here.
# Amazing people Respectful people Supporting innovation and career development Great benefits.
# this company has very much pros.
# great place to Organizational Effectiveness: Salário bom bons benefcios bom ambiente would recommend working here .
# good benefits, nice environment, helpful team, many resources.
# very skillful team Emotional Connection: apple is about the experience and the mood .
# it's one of the most exciting companies to work for and they teach you a lot about how to interact with people through communication and setting the Extrinsic Rewards: good pay - good benefits (private healthcare, stocks, discount) - schedule known 2 weeks in advance .
# people advantages salary stocks products saving.
# great benefits and stock options and pay .
#
# BART Summary:
# Direct Management: Great work environment and good work life balance and no work pressure.
# The team trusts employees and gives freedom to create your own schedule.
# Dental, vision, health are offered to both part- Organizational Alignment: Great team and great progression towards something you want to do and grow further.
# Good healthcare benefits for us.
# Every day was different, got to meet so many amazing people.
# Engagement: Employees at Apple have the opportunity to work on cutting-edge projects and products that are shaping the future.
# Apple offers a range of benefits to its employees, including health insurance, 401( Innovation: Great place to work, lots of benefits, growth opportunities.
# Best team in the industry.
# Super intelligent founders.
# Organizational Effectiveness: Good benefits, nice environment, helpful team, many resources.
# Very skillful team.
# Good management.
# Interesting tasks.
# Emotional Connection: Apple is about the experience and the mood.
# The company was respectful with mental health and time off..
# it was chill.
# Extrinsic Rewards: Great people Very good compensation.
# Great benefits and stock options and pay.
# Discounts, peers, casual, flexible, promotion.
#
# --- CONs ---
#
# T5 Summary:
# Direct Management: contract workers are kept separate from Apple employees when in person .
# contract workers get paid significantly less than employees .
# it will take you a while to move up to new position .
# Organizational Alignment: leadership environment Bad culture Don’t uphold company vision and credo Dishonest .
# retail political views are worse than corporate views .
# Engagement: pressure is high during launch.
# find some good job easy and simple and quick delivery my way of work with Gmail account .
# sometimes management disagreements, depending on leadership Long hours, especially in mall Innovation: -Apple did an exceptional job handling the pandemic in the beginning .
# but with a changed society it just doesn't work .
# supporting the Communists in china.
# Organizational Effectiveness: che provengono da altri settori e non hanno a volte le competenze necessarie per il ruolo  Emotional Connection: ninguna que deba remarcar ahora.
# Long hours Mentally and physically draining.
# sometimes the pace can be fast .
# Constantly talking all day is drain Extrinsic Rewards: hard work requires, sometimes busy and tiring .
# not great year bonus, although most people in college would gladly have this opportunity regardless of pay .
#
# BART Summary:
# Direct Management: It's perfect and the owners are especially nice.
# No opportunities to grow beyond this role.
# Contract workers are kept separate from Apple employees when in person.
# Organizational Alignment: This is a company that strives to be the best.
# Not really a con..
# I surprisingly found their workflow very disorganized.
# Absurd targets and expectations and little to no support from management.
# Engagement: High expectations: Apple is known for having high expectations for its employees.
# Long hours: Depending on the role, working at Apple may require long hours, including evenings and weekends.
# Competition for promotions Innovation: Retail needs to be torn down to the studs and rebuilt.
# Let people work from home.
# Open up leadership roles.
# You've got INCREDIBLE talent there - quit burning through Organizational Effectiveness: High pace environment.
# Too much press, no life and work balance, too many paper/report.
# Lack of people skills throughout leaders across differ.
# Emotional Connection: Long hours Mentally and physically draining.
# Lots of politics in the workplace, and been to many other branches and still have the same toxic politics at times.
# Extrinsic Rewards: Food not free - Buses didn't go to my housing that they provided - In my team, not many opportunities to socialize like other interns - Don't offer return full time positions.
# ----------------------------------------
